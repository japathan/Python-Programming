# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL'

# %%
os.chdir('C:\\Users\\DELL\\Downloads')

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('Python_Credit_Risk_XTrain_qxvwcf (2).csv')
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df=pd.read_csv('Python_Credit_Risk_XTrain_qxvwcf (2).csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x=df.iloc[:,0:14].values

# %%
x
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 1],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 0],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 0]],
#       dtype=object)

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imp.fit(x[:,7:11])
x[:,7:11] = imputer.transform(x[:,7:11])

# %%
x
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 1],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 0],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 0]],
#       dtype=object)

# %%
df1=df

# %%
df1['Loan_Status']=df1['Loan_Status'].fillna(df1['Loan_Status'].mean())

# %%
df1['LoanAmount']=df1['LoanAmount'].fillna(df1['LoanAmount'].mean())

# %%
df1['Loan_Amount_Term']=df1['Loan_Amount_Term'].fillna(df1['Loan_Amount_Term'].mean())

# %%
df1['CoapplicantIncome']=df1['CoapplicantIncome'].fillna(df1['CoapplicantIncome'].mean())

# %%
df1['ApplicantIncome']=df1['ApplicantIncome'].fillna(df1['ApplicantIncome'].mean())

# %%
df1['Credit_History']=df1['Credit_History'].fillna(df1['Credit_History'].mean())

# %%
df1.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area  Loan_Status  Total_Income
# 609             1.0         Rural            1        2900.0
# ...

# %%
from sklearn.impute import SimpleImputer
imp=SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer = imp.fit(x[:,1:2])
x[:,1:2] = imputer.transform(x[:,1:2])

# %%
x
# Out:
# array([['LP001002', 'Male', 'No', ..., 1.0, 'Urban', 1],
#        ['LP001003', 'Male', 'Yes', ..., 1.0, 'Rural', 0],
#        ['LP001005', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ['LP002984', 'Male', 'Yes', ..., 1.0, 'Urban', 1],
#        ['LP002990', 'Female', 'No', ..., 0.0, 'Semiurban', 0]],
#       dtype=object)

# %%
df1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
### EXPLORING DATA ###

# %%
df1list=['ApplicantIncome','CoapplicantIncome']
df2=df1['Total_Income']=df1[df1list].sum(axis=1)

# %%
df2.head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 65   LP001225    Male     Yes          0  Graduate            No
# 128  LP001451    Male     Yes          1  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# 34             12500             3000.0       320.0             360.0
# 54             11500                0.0       286.0             360.0
# 65              5726             4595.0       258.0             360.0
# 128            10513             3850.0       160.0             180.0
#
#      Credit_History Property_Area  Loan_Status  Total_Income
# 9               1.0     Semiurban            0       23809.0
# ...

# %%
df1.loc[(df1['Total_Income']>10000) & (df1.Loan_Status==0)]
df2=df1.loc[(df1['Total_Income']>10000) & (df1.Loan_Status==0)]

# %%
df2.head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 65   LP001225    Male     Yes          0  Graduate            No
# 128  LP001451    Male     Yes          1  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# 34             12500             3000.0       320.0             360.0
# 54             11500                0.0       286.0             360.0
# 65              5726             4595.0       258.0             360.0
# 128            10513             3850.0       160.0             180.0
#
#      Credit_History Property_Area  Loan_Status  Total_Income
# 9               1.0     Semiurban            0       23809.0
# ...

# %%
df2.shape
# Out:
# (29, 14)

# %%
df3=df2.loc[(df2['Property_Area']=='Urban')]

# %%
df3
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 128  LP001451    Male     Yes          1  Graduate           Yes
# 180  LP001633    Male     Yes          1  Graduate            No
# 199  LP001673    Male      No          0  Graduate           Yes
# 245  LP001813    Male      No          0  Graduate           Yes
# 254  LP001844    Male      No          0  Graduate           Yes
# 417  LP002342    Male     Yes          2  Graduate           Yes
# 438  LP002403    Male      No          0  Graduate           Yes
# 487  LP002547    Male     Yes          1  Graduate            No
# 581  LP002893    Male      No          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0       286.0             360.0
# ...

# %%
df3.shape
# Out:
# (11, 14)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
## EXPLORING DATA ANALYSIS ###
## LOAN GRANT CONDITIONS##

# APPLICANT AND CO-APPLICANT INCOME SHOULD BE GREATER THAN ,EQUAL TO 10,000 Rs#
## APPLICANT SHOULD HAVE NO ANY PREVIOUS LOAN HISTORY ##

# %%
plt.figure(figsize=(10,10))
sns.pointplot(df2['Total_Income'],df2['Loan_ID'])
# Out:
# C:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total_Income', ylabel='Loan_ID'>

# %%
# APPLICANT AND CO-APPLICANT INCOME SHOULD BE GREATER THAN ,EQUAL TO 20,000 Rs#
## APPLICANT SHOULD HAVE NO ANY PREVIOUS LOAN HISTORY ##

df2_20000=df1.loc[(df1['Total_Income']>20000) & (df1.Loan_Status==0)]

# %%
df2_20000
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 183  LP001637    Male     Yes          1  Graduate            No
# 284  LP001922    Male     Yes          0  Graduate            No
# 308  LP001996    Male      No          0  Graduate            No
# 369  LP002191    Male     Yes          0  Graduate            No
# 409  LP002317    Male     Yes         3+  Graduate            No
# 417  LP002342    Male     Yes          2  Graduate           Yes
# 581  LP002893    Male      No          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0  349.000000             360.0
# 183            33846                0.0  260.000000             360.0
# 284            20667                0.0  146.412162             360.0
# ...

# %%
import pandas as pd
plt.figure(figsize=(10,5))
sns.barplot(x='Loan_ID',y='Total_Income',data=df2_20000)
plt.show()

# %%
# APPLICANT AND CO-APPLICANT INCOME SHOULD BE GREATER THAN ,EQUAL TO 10,000 Rs#
## APPLICANT SHOULD HAVE NO ANY PREVIOUS LOAN HISTORY ##
### APPLICANT SHOULD BE FROM URBAN PROPERTY AREA ###

# %%
import pandas as pd
plt.figure(figsize=(15,5))
sns.barplot(x='Loan_ID',y='Total_Income',data=df3)
plt.show()

# %%
df3_20000=df2_20000.loc[(df2_20000['Property_Area']=='Urban')]

# %%
# APPLICANT AND CO-APPLICANT INCOME SHOULD BE GREATER THAN ,EQUAL TO 10,000 Rs#
## APPLICANT SHOULD HAVE NO ANY PREVIOUS LOAN HISTORY ##
### APPLICANT SHOULD BE FROM URBAN PROPERTY AREA ###
df3_20000=df2_20000.loc[(df2_20000['Property_Area']=='Urban')]

# %%
import pandas as pd
plt.figure(figsize=(10,10))
sns.barplot(x='Loan_ID',y='Total_Income',data=df3_20000)
plt.show()
